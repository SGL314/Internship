# %% [markdown]
# ## Biblotecas

# %%
import sys
# !{sys.executable} -m pip install datasets matplotlib transformers


from datasets import Dataset

import matplotlib.pyplot as plt
from transformers import BertTokenizerFast
import time as tm
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: datasets in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (3.6.0)
# Requirement already satisfied: matplotlib in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (3.10.3)
# Requirement already satisfied: transformers in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (4.52.4)
# Requirement already satisfied: filelock in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from datasets) (2.3.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from datasets) (20.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from datasets) (2.3.0)
# Requirement already satisfied: requests>=2.32.2 in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from datasets) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from datasets) (0.32.5)
# Requirement already satisfied: packaging in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.12.12)
# Requirement already satisfied: contourpy>=1.0.1 in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from matplotlib) (4.58.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: regex!=2019.12.17 in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from transformers) (0.5.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from huggingface-hub>=0.24.0->datasets) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from huggingface-hub>=0.24.0->datasets) (1.1.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.1)
# Requirement already satisfied: idna>=2.0 in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.10)
# Requirement already satisfied: six>=1.5 in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (2025.4.26)
# Requirement already satisfied: pytz>=2020.1 in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/eba/Downloads/Internship/.venv/lib/python3.12/site-packages (from pandas->datasets) (2025.2)

# %% [markdown]
# ## Data

# %%
# Carregar texto do livro
with open("a_revolucao_dos_bichos.txt", "r", encoding="utf-8") as f:
    livro = f.read()

# Dividir por parágrafos (ou capítulos)
paragrafos = [p.strip() for p in livro.split("\n") if len(p.strip()) > 50] 

# Visualizar alguns trechos
paragrafos[:2]

data = {
    "id": ["1"],
    "title": ["A Revolução dos Bichos"],
    "context": [paragrafos[0]],
    "question": ["Quem inspirou os animais com um discurso revolucionário?"],
    "answers": [{"text": ["Major"], "answer_start": [17]}]  # ajuste conforme necessário
}

# %% [markdown]
# ## Pipeline

# %%
init = tm.time()
dataset = Dataset.from_dict(data)
tokenizer = BertTokenizerFast.from_pretrained("bert-base-uncased")

def preprocess(example):
    inputs = tokenizer(
        example["question"],
        example["context"],
        truncation=True,
        padding="max_length",
        max_length=384,
        return_offsets_mapping=True
    )

    # Pega posição inicial da resposta
    answer = example["answers"]["text"][0]
    start_char = example["answers"]["answer_start"][0]
    end_char = start_char + len(answer)

    # Offset mapping: onde cada token aparece no texto original
    offsets = inputs["offset_mapping"]

    start_pos = end_pos = None
    for i, (start, end) in enumerate(offsets):
        if start <= start_char < end:
            start_pos = i
        if start < end_char <= end:
            end_pos = i
            break

    # fallback caso a correspondência seja exata
    if start_pos is None:
        start_pos = 0
    if end_pos is None:
        end_pos = 0

    inputs["start_positions"] = start_pos
    inputs["end_positions"] = end_pos
    inputs.pop("offset_mapping")  # remover para evitar erro

    return inputs


encoded_dataset = dataset.map(preprocess)

from transformers import BertForQuestionAnswering, TrainingArguments, Trainer

model = BertForQuestionAnswering.from_pretrained("bert-base-uncased")

training_args = TrainingArguments(
    output_dir="./bert-qa-revolucao_001",
    num_train_epochs=2,
    per_device_train_batch_size=1,
    learning_rate=2e-5,
    weight_decay=0.01,
    logging_steps=10,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=encoded_dataset,
)

trainer.train()


# Seu código aqui

from transformers import pipeline

qa_pipeline = pipeline("question-answering", model=model, tokenizer=tokenizer)
# Out:
# Map: 100%|██████████| 1/1 [00:00<00:00,  4.46 examples/s]
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 48
#      44 encoded_dataset = dataset.map(preprocess)
#      46 from transformers import BertForQuestionAnswering, TrainingArguments, Trainer
# ---> 48 model = BertForQuestionAnswering.from_pretrained("bert-base-uncased")
#      50 training_args = TrainingArguments(
#      51     output_dir="./bert-qa-revolucao_001",
#      52     num_train_epochs=2,
#    (...)     56     logging_steps=10,
#      57 )
#      59 trainer = Trainer(
#      60     model=model,
#      61     args=training_args,
#      62     train_dataset=encoded_dataset,
#      63 )
#
# File ~/Downloads/Internship/.venv/lib/python3.12/site-packages/transformers/utils/import_utils.py:1885, in DummyObject.__getattribute__(cls, key)
#    1883 if (key.startswith("_") and key != "_from_config") or key == "is_dummy" or key == "mro" or key == "call":
#    1884     return super().__getattribute__(key)
# -> 1885 requires_backends(cls, cls._backends)
#
# File ~/Downloads/Internship/.venv/lib/python3.12/site-packages/transformers/utils/import_utils.py:1871, in requires_backends(obj, backends)
#    1868         failed.append(msg.format(name))
#    1870 if failed:
# -> 1871     raise ImportError("".join(failed))
#
# ImportError:
# BertForQuestionAnswering requires the PyTorch library but it was not found in your environment. Checkout the instructions on the
# installation page: https://pytorch.org/get-started/locally/ and follow the ones that match your environment.
# Please note that you may need to restart your runtime after installation.

# %% [markdown]
# ## Questions

# %%
resposta = qa_pipeline({
    "context": paragrafos[0],
    "question": "Napoleão morre?"
})

print("1_Resposta:", resposta["answer"])

result = sum(range(1000000))
end_time = time.time()
execution_time = end_time - start_time
print(f"1_Tempo de execução: {execution_time:.4f} segundos")


# step = 250
# teto = 15000
# min = 5000
# tokens = [min+x*step for x in range((int) ((teto-min)/step+1))]
# for qtdTokens in tokens:
#     qtd = (int) (qtdTokens)
#     tempo = takeTime(filecontent[0:qtd],qtd)
#     tempos.append(tempo)
#     print(f"Tokens: {qtd}; Tempo: {tempo}s")

# plt.plot(tokens,tempos,marker="")
# plt.xlabel(f"Quantidade de Tokens {min} -> {teto} step {step}")
# plt.ylabel("Tempo de Greação (s)")
# plt.title("Tempo de Geração (s) vs. Quantidade de Tokens c/ armazenamento")
# plt.grid(True)
# plt.show()
